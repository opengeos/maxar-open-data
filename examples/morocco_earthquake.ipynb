# %% [markdown]
# [![image](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/opengeos/maxar-open-data/blob/master/examples/morocco_earthquake.ipynb)
# [![image](https://img.shields.io/badge/Open-Planetary%20Computer-black?style=flat&logo=microsoft)](https://pccompute.westeurope.cloudapp.azure.com/compute/hub/user-redirect/git-pull?repo=https://github.com/opengeos/maxar-open-data&urlpath=lab/tree/maxar-open-data/examples/morocco_earthquake&branch=master)
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/maxar-open-data/blob/master/examples/morocco_earthquake.ipynb)
# [![image](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/opengeos/maxar-open-data/master?urlpath=lab%2Ftree%2Fexamples)
#
# **Visualizing Maxar Open Data for the 2023 Morocco Earthquake with Leafmap**
#
# The [Maxar Open Data Program](https://www.maxar.com/open-data) provides pre- and post-event high-resolution satellite imagery in support of emergency planning, risk assessment, monitoring of staging areas and emergency response, damage assessment, and recovery. Check out the links below for more information.
# - [Maxar Open Data Program](https://www.maxar.com/open-data)
# - [Maxar Open Data on AWS](https://registry.opendata.aws/maxar-open-data/)
# - [Maxar Open Data on STAC Index](https://stacindex.org/catalogs/maxar-open-data-catalog-ard-format#/)
# - [Maxar Open Data on STAC Browser](https://radiantearth.github.io/stac-browser/#/external/maxar-opendata.s3.amazonaws.com/events/catalog.json?.language=en)
#
# The Maxar Open Data STAC catalog URL is: https://maxar-opendata.s3.amazonaws.com/events/catalog.json

# %%
# !pip install -U leafmap geopandas cogeo-mosaic

# %%
import leafmap

# %% [markdown]
# Retrieve all collections from the Maxar Open Data STAC catalog. Each collection represents a single event.

# %%
leafmap.maxar_collections()
# Out:
# ['BayofBengal-Cyclone-Mocha-May-23',
#  'Emilia-Romagna-Italy-flooding-may23',
#  'Gambia-flooding-8-11-2022',
#  'Hurricane-Fiona-9-19-2022',
#  'Hurricane-Ian-9-26-2022',
#  'Hurricane-Idalia-Florida-Aug23',
#  'Indonesia-Earthquake22',
#  'Kahramanmaras-turkey-earthquake-23',
#  'Kalehe-DRC-Flooding-5-8-23',
#  'Marshall-Fire-21-Update',
#  'Maui-Hawaii-fires-Aug-23',
#  'McDougallCreekWildfire-BC-Canada-Aug-23',
#  'Morocco-Earthquake-Sept-2023',
#  'NWT-Canada-Aug-23',
#  'New-Zealand-Flooding22',
#  'New-Zealand-Flooding23',
#  'Sudan-flooding-8-22-2022',
#  'afghanistan-earthquake22',
#  'cyclone-emnati22',
#  'ghana-explosion22',
#  'kentucky-flooding-7-29-2022',
#  'pakistan-flooding22',
#  'shovi-georgia-landslide-8Aug23',
#  'southafrica-flooding22',
#  'tonga-volcano21',
#  'volcano-indonesia21',
#  'yellowstone-flooding22']

# %% [markdown]
# Retrieve all collections for a specific event:

# %%
collections = leafmap.maxar_child_collections('Morocco-Earthquake-Sept-2023')
print(f"The number of collections: {len(collections)}")
# Out:
# The number of collections: 22

# %%
collections.sort()
collections
# Out:
# ['10300100CB8C5600',
#  '10300100CBAF7D00',
#  '10300100E5404900',
#  '10300100E5A0A100',
#  '10300100EB8B4500',
#  '10300100EBC1A000',
#  '10300100ECC53700',
#  '10300100ED11EA00',
#  '10300500CFF91800',
#  '10300500E4F91400',
#  '10300500E4F91500',
#  '10300500E4F91700',
#  '10300500E4F91800',
#  '10300500E4F91900',
#  '10400100797DAC00',
#  '1040010083289000',
#  '10400100889ABF00',
#  '104001008A8E9800',
#  '104001008B75BB00',
#  '1040050047DC6400',
#  '1040050057DC8500',
#  '1050050030DE8900']

# %% [markdown]
# Retrieve all items (tiles) for a specific collection and generate the footprints:

# %%
gdf = leafmap.maxar_items(
    collection_id='Morocco-Earthquake-Sept-2023', 
    child_id='10300100ECC53700', 
    return_gdf=True, 
    assets=['visual'])
gdf.head()
# Out:
#                                             geometry              datetime  \
# 0  POLYGON ((-8.99837 30.61125, -8.99837 30.59612...  2023-09-10T11:46:24Z
# 1  POLYGON ((-9.02553 30.59894, -8.99837 30.59894...  2023-09-10T11:46:24Z
# 2  POLYGON ((-9.02489 30.55382, -8.99837 30.55383...  2023-09-10T11:46:25Z
# 3  POLYGON ((-9.02435 30.50870, -8.99837 30.50871...  2023-09-10T11:46:25Z
# 4  POLYGON ((-9.02396 30.46358, -8.99837 30.46359...  2023-09-10T11:46:25Z
#
#   platform   gsd ard_metadata_version        catalog_id  utm_zone  \
# 0     WV02  0.83                0.0.1  10300100ECC53700        29
# 1     WV02  0.82                0.0.1  10300100ECC53700        29
# 2     WV02  0.82                0.0.1  10300100ECC53700        29
# 3     WV02  0.82                0.0.1  10300100ECC53700        29
# 4     WV02  0.82                0.0.1  10300100ECC53700        29
#
#         quadkey  view:off_nadir  view:azimuth  ...  view:sun_azimuth  \
# 0  031313133131            41.5         234.2  ...             154.6
# 1  031313133133            41.5         234.2  ...             154.6
# 2  031313133311            41.4         234.4  ...             154.6
# 3  031313133313            41.4         234.6  ...             154.6
# 4  031313133331            41.4         234.8  ...             154.6
#
#    view:sun_elevation  proj:epsg  \
# 0                62.3      32629
# 1                62.3      32629
# 2                62.3      32629
# 3                62.3      32629
# 4                62.4      32629
#
#                                        proj:geometry              grid:code  \
# 0  {'type': 'Polygon', 'coordinates': [[[500155.9...  MXRA-Z29-031313133131
# 1  {'type': 'Polygon', 'coordinates': [[[497552.1...  MXRA-Z29-031313133133
# 2  {'type': 'Polygon', 'coordinates': [[[497612.6...  MXRA-Z29-031313133311
# 3  {'type': 'Polygon', 'coordinates': [[[497663.2...  MXRA-Z29-031313133313
# 4  {'type': 'Polygon', 'coordinates': [[[497699.8...  MXRA-Z29-031313133331
#
#                                            proj:bbox tile:data_area  \
# 0  497536.92626953125,3384843.75,500156.25,338652...            3.2
# 1  497552.18505859375,3379843.75,500156.25,338515...           13.6
# 2  497612.60986328125,3374843.75,500156.25,338015...           13.3
# 3  497663.26904296875,3369843.75,500156.25,337515...           13.1
# 4  497604.3701171875,3364843.75,500156.25,3370156.25           13.1
#
#    tile:clouds_area  tile:clouds_percent  \
# 0               0.0                    0
# 1               0.0                    0
# 2               0.0                    0
# 3               0.0                    0
# 4               0.0                    0
#
#                                               visual
# 0  https://maxar-opendata.s3.amazonaws.com/events...
# 1  https://maxar-opendata.s3.amazonaws.com/events...
# 2  https://maxar-opendata.s3.amazonaws.com/events...
# 3  https://maxar-opendata.s3.amazonaws.com/events...
# 4  https://maxar-opendata.s3.amazonaws.com/events...
#
# [5 rows x 21 columns]

# %% [markdown]
# Add the footprints to the map:

# %%
m = leafmap.Map()
m.add_gdf(gdf, layer_name="Footprints", zoom_to_layer=True)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7363cf1608bec1d9dfc62323e8cc477d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7363cf1608bec1d9dfc62323e8cc477d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7363cf1608bec1d9dfc62323e8cc477d = L.map(
#                 &quot;map_7363cf1608bec1d9dfc62323e8cc477d&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_7363cf1608bec1d9dfc62323e8cc477d);
#
#
#
#
#
#             var tile_layer_8db5f26d293bffe2433117d806bfef17 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7363cf1608bec1d9dfc62323e8cc477d);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_7363cf1608bec1d9dfc62323e8cc477d);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_7363cf1608bec1d9dfc62323e8cc477d
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_4f2c47f5ce8d720eafbc0139f79a29b7 = new L.Control.Draw(
#                 options
#             ).addTo( map_7363cf1608bec1d9dfc62323e8cc477d );
#             map_7363cf1608bec1d9dfc62323e8cc477d.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_7363cf1608bec1d9dfc62323e8cc477d.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_ee6534a16bbff056340542045c6c7dcf = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_7363cf1608bec1d9dfc62323e8cc477d.addControl(measure_control_ee6534a16bbff056340542045c6c7dcf);
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_7363cf1608bec1d9dfc62323e8cc477d.setView(e.geocode.center, 11);
#             }).addTo(map_7363cf1608bec1d9dfc62323e8cc477d);
#
#
#
#             map_7363cf1608bec1d9dfc62323e8cc477d.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#         funct

# %% [markdown]
# Retrieve the COG URLs for all tiles in a collection:

# %%
images = gdf['visual'].tolist()
images[:5]
# Out:
# ['https://maxar-opendata.s3.amazonaws.com/events/Morocco-Earthquake-Sept-2023/ard/29/031313133131/2023-09-10/10300100ECC53700-visual.tif',
#  'https://maxar-opendata.s3.amazonaws.com/events/Morocco-Earthquake-Sept-2023/ard/29/031313133133/2023-09-10/10300100ECC53700-visual.tif',
#  'https://maxar-opendata.s3.amazonaws.com/events/Morocco-Earthquake-Sept-2023/ard/29/031313133311/2023-09-10/10300100ECC53700-visual.tif',
#  'https://maxar-opendata.s3.amazonaws.com/events/Morocco-Earthquake-Sept-2023/ard/29/031313133313/2023-09-10/10300100ECC53700-visual.tif',
#  'https://maxar-opendata.s3.amazonaws.com/events/Morocco-Earthquake-Sept-2023/ard/29/031313133331/2023-09-10/10300100ECC53700-visual.tif']

# %% [markdown]
# Download the COGs to a local directory:

# %%
leafmap.maxar_download(images[:2])

# %% [markdown]
# Create a mosaic json file for the collection. You need to install `cogeo-mosaic` first using `pip install cogeo-mosaic`. Creating a mosaic json file might take a few minutes. Please be patient.

# %%
# leafmap.create_mosaicjson(images, output='10300100ECC53700.json')

# %% [markdown]
# Make the mosaic json file available on the web, then you can add the mosaic to the map:

# %%
m = leafmap.Map(height='600px')
m.add_basemap('SATELLITE')
url = 'https://open.gishub.org/maxar-open-data/datasets/Morocco-Earthquake-Sept-2023/10300100ECC53700.json'
m.add_stac_layer(url, name="Mosaic")
m.add_gdf(gdf, layer_name="Footprints")
m
# Out:
# Google Maps API key is required to use Google Maps. You can generate one from https://bit.ly/3sw0THG and use geemap.set_api_key(), defaulting to Esri basemaps.
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea65bdda05240c4a313716d56c038f90 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea65bdda05240c4a313716d56c038f90&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea65bdda05240c4a313716d56c038f90 = L.map(
#                 &quot;map_ea65bdda05240c4a313716d56c038f90&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_ea65bdda05240c4a313716d56c038f90);
#
#
#
#
#
#             var tile_layer_3fb929643ea7f5a17ca6df05dfc8951d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ea65bdda05240c4a313716d56c038f90);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_ea65bdda05240c4a313716d56c038f90);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_ea65bdda05240c4a313716d56c038f90
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_cbcbb80241b314b2611fa099bf53b36a = new L.Control.Draw(
#                 options
#             ).addTo( map_ea65bdda05240c4a313716d56c038f90 );
#             map_ea65bdda05240c4a313716d56c038f90.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_ea65bdda05240c4a313716d56c038f90.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_c6ae6bc455a6cc0fdb7d375b557448f9 = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_ea65bdda05240c4a313716d56c038f90.addControl(measure_control_c6ae6bc455a6cc0fdb7d375b557448f9);
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_ea65bdda05240c4a313716d56c038f90.setView(e.geocode.center, 11);
#             }).addTo(map_ea65bdda05240c4a313716d56c038f90);
#
#
#
#             map_ea65bdda05240c4a313716d56c038f90.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             v

# %% [markdown]
# Retrieve the footprint of all tiles for a specific event. This might take 15+ minutes. Please be patient.

# %%
# gdf = leafmap.maxar_all_items(
#     collection_id='Morocco-Earthquake-Sept-2023',
#     return_gdf=True, 
#     verbose=True
#     )
# gdf.to_file('maxar_footprints.geojson', driver='GeoJSON')
# gdf

# %% [markdown]
# Add the footprints to the map:

# %%
m = leafmap.Map(center=[31.35874, -8.78226], zoom=8)
url = 'https://open.gishub.org/maxar-open-data/datasets/Morocco-Earthquake-Sept-2023.geojson'
m.add_geojson(url, layer_name="Footprints")
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f6f494acb73b417ecfa7a955106180a9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f6f494acb73b417ecfa7a955106180a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f6f494acb73b417ecfa7a955106180a9 = L.map(
#                 &quot;map_f6f494acb73b417ecfa7a955106180a9&quot;,
#                 {
#                     center: [31.35874, -8.78226],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_f6f494acb73b417ecfa7a955106180a9);
#
#
#
#
#
#             var tile_layer_4c2e6bec21abdb22e6914a25f917d334 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f6f494acb73b417ecfa7a955106180a9);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_f6f494acb73b417ecfa7a955106180a9);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_f6f494acb73b417ecfa7a955106180a9
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_3f8a015578df5244d2ab7961a94daa90 = new L.Control.Draw(
#                 options
#             ).addTo( map_f6f494acb73b417ecfa7a955106180a9 );
#             map_f6f494acb73b417ecfa7a955106180a9.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_f6f494acb73b417ecfa7a955106180a9.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_4e9fa78985433d83f948b8d5135ae47c = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_f6f494acb73b417ecfa7a955106180a9.addControl(measure_control_4e9fa78985433d83f948b8d5135ae47c);
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_f6f494acb73b417ecfa7a955106180a9.setView(e.geocode.center, 11);
#             }).addTo(map_f6f494acb73b417ecfa7a955106180a9);
#
#
#
#             map_f6f494acb73b417ecfa7a955106180a9.fitBounds(
#                 [[31.35874, -8.78226], [31.35874, -8.78226]],
#                 {&quot;maxZoom&quot;: 8}
